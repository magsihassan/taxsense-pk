# %%
import os
from pathlib import Path
from dotenv import load_dotenv
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone, ServerlessSpec

load_dotenv()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8488\1435846603.py:4: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       3 from dotenv import load_dotenv
#       4 from langchain_community.document_loaders import PyPDFLoader
#       5 from langchain_text_splitters import RecursiveCharacterTextSplitter
#       6 from langchain_huggingface import HuggingFaceEmbeddings
# ----> 7 from langchain_pinecone import PineconeVectorStore
#       8 from pinecone import Pinecone, ServerlessSpec
#       9
#      10 load_dotenv()
#
# File ~\Desktop\tax-assistant\.venv\Lib\site-packages\langchain_pinecone\__init__.py:1
# ----> 1 from langchain_pinecone.embeddings import PineconeEmbeddings, PineconeSparseEmbeddings
#       2 from langchain_pinecone.rerank import PineconeRerank
#       3 from langchain_pinecone.vectorstores import Pinecone, PineconeVectorStore
#
# File ~\Desktop\tax-assistant\.venv\Lib\site-packages\langchain_pinecone\embeddings.py:6
#       4 from langchain_core.embeddings import Embeddings
#       5 from langchain_core.utils import secret_from_env
# ----> 6 from pinecone import Pinecone as PineconeClient  # type: ignore[import-untyped]
#       7 from pinecone import (
#       8     PineconeAsyncio as PineconeAsyncioClient,  # type: ignore[import-untyped]
#       9 )
#      10 from pinecone import SparseValues
#
# ImportError: cannot import name 'Pinecone' from 'pinecone' (unknown location)
